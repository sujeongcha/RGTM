# %%
import pandas as pd
from sodapy import Socrata

client = Socrata("data.cityofnewyork.us", 
                 "phCy46lgZSogk7QgnXpSoMkSl",
                 username="sujeongcha90@gmail.com",
                 password="Housing311")

# %%
# Loading data for Manhattan (separate load by year due to large data volume)
Manhattan_2015 = client.get("erm2-nwe9", 
                            where="borough='MANHATTAN' AND created_date between '2015-01-01T00:00:00.000' and '2015-12-31T23:59:59.000'", limit=500000)
Manhattan_2016 = client.get("erm2-nwe9", 
                            where="borough='MANHATTAN' AND created_date between '2016-01-01T00:00:00.000' and '2016-12-31T23:59:59.000'", limit=500000)
Manhattan_2017 = client.get("erm2-nwe9", 
                            where="borough='MANHATTAN' AND created_date between '2017-01-01T00:00:00.000' and '2017-12-31T23:59:59.000'", limit=500000)
Manhattan_2018 = client.get("erm2-nwe9", 
                            where="borough='MANHATTAN' AND created_date between '2018-01-01T00:00:00.000' and '2018-12-31T23:59:59.000'", limit=500000)
Manhattan_2019 = client.get("erm2-nwe9", 
                            where="borough='MANHATTAN' AND created_date between '2019-01-01T00:00:00.000' and '2019-12-31T23:59:59.000'", limit=500000)

# %%
# Appending the dataframes row-wise into one dataframe

comp2015 = pd.DataFrame(Manhattan_2015)
comp2016 = pd.DataFrame(Manhattan_2016)
comp2017 = pd.DataFrame(Manhattan_2017)
comp2018 = pd.DataFrame(Manhattan_2018)
comp2019 = pd.DataFrame(Manhattan_2019)

complaints_man = comp2015.append([comp2016, comp2017, comp2018, comp2019], sort=False)
pd.set_option('display.max_columns', 500)
display(complaints_man.head())
# Out:
#   address_type agency                              agency_name         bbl  \
# 0      LATLONG    DPR       Department of Parks and Recreation  1017210014
# 1      LATLONG    DPR       Department of Parks and Recreation  1018260006
# 2      LATLONG    DPR       Department of Parks and Recreation         NaN
# 3      LATLONG  DOHMH  Department of Health and Mental Hygiene  1000150022
# 4      LATLONG  DOHMH  Department of Health and Mental Hygiene  1021750045
#
#      borough bridge_highway_direction bridge_highway_name  \
# 0  MANHATTAN                      NaN                 NaN
# 1  MANHATTAN                      NaN                 NaN
# 2  MANHATTAN                      NaN                 NaN
# 3  MANHATTAN                      NaN                 NaN
# 4  MANHATTAN                      NaN                 NaN
#
#   bridge_highway_segment      city              closed_date community_board  \
# 0                    NaN  NEW YORK  2015-09-27T12:04:40.000    01 MANHATTAN
# 1                    NaN  NEW YORK  2015-09-13T15:38:22.000    01 MANHATTAN
# 2                    NaN  NEW YORK  2015-09-27T15:10:09.000    01 MANHATTAN
# 3                    NaN  NEW YORK  2015-03-21T06:22:16.000    01 MANHATTAN
# 4                    NaN  NEW YORK  2015-07-04T06:37:16.000    01 MANHATTAN
#
#        complaint_type             created_date cross_street_1 cross_street_2  \
# 0        Damaged Tree  2015-08-15T08:20:29.000            NaN            NaN
# 1        Damaged Tree  2015-09-04T22:32:12.000            NaN            NaN
# 2        Damaged Tree  2015-09-20T13:36:46.000            NaN            NaN
# 3  Food Establishment  2015-01-19T17:27:16.000            NaN            NaN
# 4  Food Establishment  2015-05-04T14:20:46.000            NaN            NaN
#
#                        descriptor                 due_date facility_type  \
# 0  Tree Alive - in Poor Condition  2015-08-25T08:20:29.000           N/A
# 1           Tree Leaning/Uprooted  2015-09-14T10:02:03.000           N/A
# 2  Branch or Limb Has Fallen Down  2015-09-29T05:53:36.000           N/A
# 3                      Pet/Animal  2015-03-20T17:27:16.000           N/A
# 4                  Letter Grading  2015-07-03T14:20:46.000           N/A
#
#                incident_address incident_zip intersection_street_1  \
# 0  22-30 MOUNT MORRIS PARK WEST        10027                   NaN
# 1         241 WEST 110TH STREET        10026                   NaN
# 2          244 BRADHURST AVENUE        10039                   NaN
# 3                21 WEST STREET        10004                   NaN
# 4                 4740 BROADWAY        10040                   NaN
#
#   intersection_street_2 landmark            latitude  \
# 0                   NaN      NaN   40.80514830349886
# 1                   NaN      NaN  40.800597190258756
# 2                   NaN      NaN   40.82960323117124
# 3                   NaN      NaN   40.70636316025726
# 4                   NaN      NaN  40.864899230397484
#
#                                             location  \
# 0  {'latitude': '40.80514830349886', 'longitude':...
# 1  {'latitude': '40.800597190258756', 'longitude'...
# 2  {'latitude': '40.82960323117124', 'longitude':...
# 3  {'latitude': '40.70636316025726', 'longitude':...
# 4  {'latitude': '40.864899230397484', 'longitude'...
#
#                 location_type           longitude open_data_channel_type  \
# 0                         NaN  -73.94522175482079                 MOBILE
# 1                         NaN  -73.95736871698621                 MOBILE
# 2                         NaN  -73.93872265646418                 MOBILE
# 3  Restaurant/Bar/Deli/Bakery  -74.01561742791233                 MOBILE
# 4  Restaurant/Bar/Deli/Bakery  -73.92765233015238                 MOBILE
#
#   park_borough park_facility_name resolution_action_updated_date  \
# 0    MANHATTAN        Unspecified        2015-09-27T12:03:55.000
# 1    MANHATTAN        Unspecified        2015-09-13T15:38:14.000
# 2    MANHATTAN        Unspecified        2015-09-27T15:09:30.000
# 3    MANHATTAN        Unspecified        2015-03-21T06:17:14.000
# 4    MANHATTAN        Unspecified        2015-07-04T06:30:41.000
#
#                               resolution_description road_ramp  status  \
# 0  The Department of Parks and Recreation has cor...       NaN  Closed
# 1  The Department of Parks and Recreation has cor...       NaN  Closed
# 2  The Department of Parks and Recreation has cor...       NaN  Closed
# 3  The Department of Health and Mental Hygiene ha...       NaN  Closed
# 4  The Department of Health and Mental Hygiene ha...       NaN  Closed
#
#               street_name taxi_company_borough taxi_pick_up_location  \
# 0  MOUNT MORRIS PARK WEST                  NaN                   NaN
# 1       WEST 110TH STREET                  NaN                   NaN
# 2        BRADHURST AVENUE                  NaN                   NaN
# 3             WEST STREET                  NaN                   NaN
# 4                BROADWAY                  NaN                   NaN
#
#   unique_key vehicle_type x_coordinate_state_plane y_coordinate_state_plane
# 0   31315670          NaN                   999415                   232619
# 1   31461589          NaN                   996053                   230959
# 2   31577639          NaN                  1001208                   241530
# 3   29750613          NaN                   979920                   196624
# 4   30539470          NaN                  1004261                   254392

# %%
# Restricting Complaint types to
# Rodent/Hazardous Materials/Sidewalk Condition/WATER LEAK/Noise - Residential/Noise - Commercial

condition = ['Rodent', 'Hazardous Materials', 'Sidewalk Condition', 'WATER LEAK', 'Noise - Residential', 'Noise - Commercial']

def drop_complaints(data):
    result = data[data['complaint_type'].isin(condition)]
    return result

six_comp_man = drop_complaints(complaints_man)
display(six_comp_man.head())
# Out:
#       address_type agency                   agency_name         bbl  \
# 625   INTERSECTION    DOT  Department of Transportation         NaN
# 852   INTERSECTION    DOT  Department of Transportation         NaN
# 1076       ADDRESS    DOT  Department of Transportation  1000220024
# 1095  INTERSECTION    DOT  Department of Transportation         NaN
# 1236       ADDRESS    DOT  Department of Transportation  1016760001
#
#         borough bridge_highway_direction bridge_highway_name  \
# 625   MANHATTAN                      NaN                 NaN
# 852   MANHATTAN                      NaN                 NaN
# 1076  MANHATTAN                      NaN                 NaN
# 1095  MANHATTAN                      NaN                 NaN
# 1236  MANHATTAN                      NaN                 NaN
#
#      bridge_highway_segment      city              closed_date  \
# 625                     NaN  NEW YORK  2016-03-04T12:37:17.000
# 852                     NaN  NEW YORK  2016-01-13T11:41:07.000
# 1076                    NaN  NEW YORK  2016-01-21T09:58:01.000
# 1095                    NaN  NEW YORK  2016-01-08T18:07:28.000
# 1236                    NaN  NEW YORK  2016-01-04T10:38:18.000
#
#      community_board      complaint_type             created_date  \
# 625     12 MANHATTAN  Sidewalk Condition  2015-11-27T19:39:43.000
# 852     04 MANHATTAN  Sidewalk Condition  2015-12-04T14:51:42.000
# 1076    01 MANHATTAN  Sidewalk Condition  2015-12-09T13:58:44.000
# 1095    05 MANHATTAN  Sidewalk Condition  2015-12-09T08:32:02.000
# 1236    11 MANHATTAN  Sidewalk Condition  2015-12-11T11:59:01.000
#
#        cross_street_1   cross_street_2                 descriptor  \
# 625               NaN              NaN         Sidewalk Staircase
# 852               NaN              NaN    Newspaper Box Complaint
# 1076   EXCHANGE PLACE    BEAVER STREET            Broken Sidewalk
# 1095              NaN              NaN  Pedestrian Ramp Defective
# 1236  EAST 104 STREET  EAST 105 STREET            Broken Sidewalk
#
#                      due_date facility_type incident_address incident_zip  \
# 625   2016-12-09T11:16:13.000           N/A              NaN        10034
# 852   2016-02-02T14:51:42.000           N/A              NaN        10036
# 1076  2016-03-14T08:21:04.000           N/A    45 NEW STREET        10004
# 1095  2016-02-07T08:32:02.000           N/A              NaN        10016
# 1236  2016-01-10T11:59:01.000           N/A    2024 2 AVENUE        10029
#
#      intersection_street_1 intersection_street_2 landmark            latitude  \
# 625       WEST  214 STREET         SEAMAN AVENUE      NaN   40.87100884264379
# 852               9 AVENUE      WEST   44 STREET      NaN   40.75973017419921
# 1076                   NaN                   NaN      NaN  40.706050677516664
# 1095              5 AVENUE      EAST   35 STREET      NaN  40.749101717507905
# 1236                   NaN                   NaN      NaN   40.78937892345934
#
#                                                location location_type  \
# 625   {'latitude': '40.87100884264379', 'longitude':...      Sidewalk
# 852   {'latitude': '40.75973017419921', 'longitude':...      Sidewalk
# 1076  {'latitude': '40.706050677516664', 'longitude'...      Sidewalk
# 1095  {'latitude': '40.749101717507905', 'longitude'...      Sidewalk
# 1236  {'latitude': '40.78937892345934', 'longitude':...      Sidewalk
#
#                longitude open_data_channel_type park_borough  \
# 625   -73.91925357768065                  PHONE    MANHATTAN
# 852   -73.99168328325673                  PHONE    MANHATTAN
# 1076  -74.01212959902071                 ONLINE    MANHATTAN
# 1095   -73.9840766057945                  PHONE    MANHATTAN
# 1236  -73.94333157738238                  PHONE    MANHATTAN
#
#      park_facility_name resolution_action_updated_date  \
# 625         Unspecified        2016-03-04T12:37:17.000
# 852         Unspecified        2016-01-13T11:41:07.000
# 1076        Unspecified        2016-01-21T09:58:01.000
# 1095        Unspecified        2016-01-08T18:07:28.000
# 1236        Unspecified        2016-01-04T10:38:18.000
#
#                                  resolution_description road_ramp  status  \
# 625   The Department of Transportation inspected the...       NaN  Closed
# 852   The Department of Transportation inspected the...       NaN  Closed
# 1076  The Department of Transportation has completed...       NaN  Closed
# 1095  The Department of Transportation inspected the...       NaN  Closed
# 1236  The Department of Transportation inspected the...       NaN  Closed
#
#      street_name taxi_company_borough taxi_pick_up_location unique_key  \
# 625          NaN                  NaN                   NaN   32079825
# 852          NaN                  NaN                   NaN   32130053
# 1076  NEW STREET                  NaN                   NaN   32164627
# 1095         NaN                  NaN                   NaN   32168214
# 1236    2 AVENUE                  NaN                   NaN   32183753
#
#      vehicle_type x_coordinate_state_plane y_coordinate_state_plane
# 625           NaN                  1006582                   256620
# 852           NaN                   986554                   216067
# 1076          NaN                   980887                   196510
# 1095          NaN                   988662                   212195
# 1236          NaN                   999942                   226874

# %%
# Cleaning up columns

comp_cleaned = six_comp_man[['complaint_type', 'latitude', 'longitude']]
comp_cleaned['GeoCode'] = list(zip(comp_cleaned.longitude, comp_cleaned.latitude))
display(comp_cleaned.head())
# Out:
# C:\Users\sujeong\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#           complaint_type            latitude           longitude  \
# 625   Sidewalk Condition   40.87100884264379  -73.91925357768065
# 852   Sidewalk Condition   40.75973017419921  -73.99168328325673
# 1076  Sidewalk Condition  40.706050677516664  -74.01212959902071
# 1095  Sidewalk Condition  40.749101717507905   -73.9840766057945
# 1236  Sidewalk Condition   40.78937892345934  -73.94333157738238
#
#                                        GeoCode
# 625    (-73.91925357768065, 40.87100884264379)
# 852    (-73.99168328325673, 40.75973017419921)
# 1076  (-74.01212959902071, 40.706050677516664)
# 1095   (-73.9840766057945, 40.749101717507905)
# 1236   (-73.94333157738238, 40.78937892345934)

# %%
comp_cleaned.to_csv(r'C:\Users\sujeong\Documents\2019 Fall NYU MSDS ■\1001 Introduction to Data Science\Project\complaints_cleanup.csv', index=False)
